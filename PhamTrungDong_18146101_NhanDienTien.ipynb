# %% [markdown]
# <a href="https://colab.research.google.com/github/TrungDong888/BTVN_AI/blob/main/PhamTrungDong_18146101_NhanDienTien.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from keras.preprocessing.image import load_img, img_to_array,array_to_img,ImageDataGenerator, image
from keras.layers import Dense,Activation,Dropout,Conv2D,MaxPooling2D,Flatten
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.preprocessing.image import img_to_array
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import load_model
from keras.models import  Sequential

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import pandas as pd
import os

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import pandas as pd

# %%
train_data = '/content/drive/MyDrive/Tiền/train'
test_data =  '/content/drive/MyDrive/Tiền/test'
val_data  =  '/content/drive/MyDrive/Tiền/validation'

# %%
from keras.engine.data_adapter import train_validation_split

# %%
data_scale = ImageDataGenerator(rescale=1. / 255,shear_range=0.2,zoom_range=0.2,horizontal_flip=True)
train_input = data_scale.flow_from_directory(train_data,target_size=(120, 120),batch_size=32,class_mode="categorical")
test_input = data_scale.flow_from_directory(test_data,target_size=(120, 120),batch_size=32,class_mode="categorical")
val_input = data_scale.flow_from_directory(val_data,target_size=(120, 120),batch_size=32,class_mode="categorical")
# Out:
# Found 131 images belonging to 11 classes.
# Found 11 images belonging to 11 classes.
# Found 78 images belonging to 11 classes.

# %%
class_name = ['200', '500', '1000', '2000', '5000', '10000', '20000', '50000', '100000', '200000','500000']

# %%
print("labels: ", class_name)
print("match class: ", train_input.class_indices)
print("Tổng cộng số loại tiền giấy: ",train_input.num_classes)
# Out:
# labels:  ['200', '500', '1000', '2000', '5000', '10000', '20000', '50000', '100000', '200000', '500000']
# match class:  {'100k': 0, '10k': 1, '1k': 2, '200 đồng': 3, '200k': 4, '20k': 5, '2k': 6, '500 đồng': 7, '500k': 8, '50k': 9, '5k': 10}
# Tổng cộng số loại tiền giấy:  11

# %%
model=Sequential()

model.add(Conv2D(32,(3,3),activation='relu',kernel_initializer='he_uniform',padding='same', input_shape=(120,120,3)))
model.add(MaxPooling2D((2,2)))
model.add(Dropout(0.25))

model.add(Conv2D(64,(3,3),activation='relu',kernel_initializer='he_uniform',padding='same'))
model.add(MaxPooling2D((2,2)))
model.add(Dropout(0.25))

model.add(Conv2D(128,(3,3),activation='relu',kernel_initializer='he_uniform',padding='same'))
model.add(MaxPooling2D((2,2)))
model.add(Dropout(0.25))

# %%
model.add(Flatten())

model.add(Dense(128,activation='relu'))
model.add(Dropout(0.25))
model.add(Dense(128,activation='relu'))
model.add(Dropout(0.25))

model.add(Dense(11,activation='softmax'))  
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 120, 120, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 60, 60, 32)       0
#  )
#
#  dropout (Dropout)           (None, 60, 60, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 60, 60, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 30, 30, 64)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 30, 30, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 30, 30, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 15, 15, 128)      0
#  2D)
#
#  dropout_2 (Dropout)         (None, 15, 15, 128)       0
#
#  flatten (Flatten)           (None, 28800)             0
#
#  dense (Dense)               (None, 128)               3686528
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 128)               16512
#
#  dropout_4 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 11)                1419
#
# =================================================================
# Total params: 3,797,707
# Trainable params: 3,797,707
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers import Adam

# %%
opt = Adam(learning_rate=0.001)
model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
money_train = model.fit(train_input,batch_size=30,epochs=50,verbose=1,validation_data=val_input)
# Out:
# Epoch 1/50
# 5/5 [==============================] - 52s 12s/step - loss: 12.0337 - accuracy: 0.1527 - val_loss: 2.3951 - val_accuracy: 0.3846
# Epoch 2/50
# 5/5 [==============================] - 12s 2s/step - loss: 3.6468 - accuracy: 0.2290 - val_loss: 2.3513 - val_accuracy: 0.3846
# Epoch 3/50
# 5/5 [==============================] - 11s 3s/step - loss: 2.2888 - accuracy: 0.3359 - val_loss: 2.3775 - val_accuracy: 0.3846
# Epoch 4/50
# 5/5 [==============================] - 12s 2s/step - loss: 2.3216 - accuracy: 0.3969 - val_loss: 2.3668 - val_accuracy: 0.3846
# Epoch 5/50
# 5/5 [==============================] - 11s 2s/step - loss: 2.2687 - accuracy: 0.4275 - val_loss: 2.2990 - val_accuracy: 0.3846
# Epoch 6/50
# 5/5 [==============================] - 11s 2s/step - loss: 2.0904 - accuracy: 0.4122 - val_loss: 2.1292 - val_accuracy: 0.3846
# Epoch 7/50
# 5/5 [==============================] - 12s 2s/step - loss: 2.0506 - accuracy: 0.4275 - val_loss: 2.1322 - val_accuracy: 0.3846
# Epoch 8/50
# 5/5 [==============================] - 11s 2s/step - loss: 1.9571 - accuracy: 0.4198 - val_loss: 2.0289 - val_accuracy: 0.3846
# Epoch 9/50
# 5/5 [==============================] - 12s 2s/step - loss: 1.8848 - accuracy: 0.4198 - val_loss: 1.9256 - val_accuracy: 0.3846
# Epoch 10/50
# 5/5 [==============================] - 11s 3s/step - loss: 1.9324 - accuracy: 0.4504 - val_loss: 2.0950 - val_accuracy: 0.3846
# Epoch 11/50
# 5/5 [==============================] - 11s 2s/step - loss: 1.8749 - accuracy: 0.4733 - val_loss: 1.8177 - val_accuracy: 0.3846
# Epoch 12/50
# 5/5 [==============================] - 11s 3s/step - loss: 1.7473 - accuracy: 0.4427 - val_loss: 1.7219 - val_accuracy: 0.3974
# Epoch 13/50
# 5/5 [==============================] - 11s 2s/step - loss: 1.6383 - accuracy: 0.4427 - val_loss: 1.7182 - val_accuracy: 0.3846
# Epoch 14/50
# 5/5 [==============================] - 11s 2s/step - loss: 1.5712 - accuracy: 0.4504 - val_loss: 1.6701 - val_accuracy: 0.3846
# Epoch 15/50
# 5/5 [==============================] - 11s 2s/step - loss: 1.4968 - accuracy: 0.4580 - val_loss: 1.6384 - val_accuracy: 0.4103
# Epoch 16/50
# 5/5 [==============================] - 11s 3s/step - loss: 1.4319 - accuracy: 0.4885 - val_loss: 1.4738 - val_accuracy: 0.4615
# Epoch 17/50
# 5/5 [==============================] - 11s 2s/step - loss: 1.3857 - accuracy: 0.5344 - val_loss: 1.4561 - val_accuracy: 0.5128
# Epoch 18/50
# 5/5 [==============================] - 12s 2s/step - loss: 1.3029 - accuracy: 0.5344 - val_loss: 1.4128 - val_accuracy: 0.5641
# Epoch 19/50
# 5/5 [==============================] - 11s 2s/step - loss: 1.3577 - accuracy: 0.4885 - val_loss: 1.4370 - val_accuracy: 0.6026
# Epoch 20/50
# 5/5 [==============================] - 11s 3s/step - loss: 1.2236 - accuracy: 0.5649 - val_loss: 1.2207 - val_accuracy: 0.6154
# Epoch 21/50
# 5/5 [==============================] - 11s 2s/step - loss: 1.2496 - accuracy: 0.5496 - val_loss: 1.0853 - val_accuracy: 0.6026
# Epoch 22/50
# 5/5 [==============================] - 12s 2s/step - loss: 1.0824 - accuracy: 0.6489 - val_loss: 1.0573 - val_accuracy: 0.6923
# Epoch 23/50
# 5/5 [==============================] - 12s 2s/step - loss: 1.2243 - accuracy: 0.5191 - val_loss: 1.2192 - val_accuracy: 0.6923
# Epoch 24/50
# 5/5 [==============================] - 11s 3s/step - loss: 1.2992 - accuracy: 0.5649 - val_loss: 1.3200 - val_accuracy: 0.7692
# Epoch 25/50
# 5/5 [==============================] - 11s 2s/step - loss: 1.1210 - accuracy: 0.6718 - val_loss: 1.1791 - val_accuracy: 0.5385
# Epoch 26/50
# 5/5 [==============================] - 11s 2s/step - loss: 1.1810 - accuracy: 0.6260 - val_loss: 1.2370 - val_accuracy: 0.6795
# Epoch 27/50
# 5/5 [==============================] - 12s 2s/step - loss: 1.0926 - accuracy: 0.6641 - val_loss: 0.9769 - val_accuracy: 0.7308
# Epoch 28/50
# 5/5 [==============================] - 11s 3s/step - loss: 1.1370 - accuracy: 0.6641 - val_loss: 1.0536 - val_accuracy: 0.7436
# Epoch 29/50
# 5/5 [==============================] - 12s 2s/step - loss: 1.0987 - accuracy: 0.6031 - val_loss: 0.8831 - val_accuracy: 0.8205
# Epoch 30/50
# 5/5 [==============================] - 11s 2s/step - loss: 0.9941 - accuracy: 0.6183 - val_loss: 1.0001 - val_accuracy: 0.7692
# Epoch 31/50
# 5/5 [==============================] - 11s 2s/step - loss: 1.0075 - accuracy: 0.6947 - val_loss: 1.2442 - val_accuracy: 0.7051
# Epoch 32/50
# 5/5 [==============================] - 11s 2s/step - loss: 0.9499 - accuracy: 0.7328 - val_loss: 0.9307 - val_accuracy: 0.7821
# Epoch 33/50
# 5/5 [==============================] - 11s 2s/step - loss: 0.8701 - accuracy: 0.7252 - val_loss: 0.8185 - val_accuracy: 0.8590
# Epoch 34/50
# 5/5 [==============================] - 11s 2s/step - loss: 0.9632 - accuracy: 0.6870 - val_loss: 0.7834 - val_accuracy: 0.7821
# Epoch 35/50
# 5/5 [==============================] - 12s 2s/step - loss: 0.8887 - accuracy: 0.7176 - val_loss: 0.7472 - val_accuracy: 0.8974
# Epoch 36/50
# 5/5 [==============================] - 11s 2s/step - loss: 0.7986 - accuracy: 0.7481 - val_loss: 0.7422 - val_accuracy: 0.8846
# Epoch 37/50
# 5/5 [==============================] - 11s 2s/step - loss: 0.7524 - accuracy: 0.7557 - val_loss: 0.6870 - val_accuracy: 0.8846
# Epoch 38/50
# 5/5 [==============================] - 11s 2s/step - loss: 0.6078 - accuracy: 0.8092 - val_loss: 0.6371 - val_accuracy: 0.9231
# Epoch 39/50
# 5/5 [==============================] - 11s 2s/step - loss: 0.6134 - accuracy: 0.7863 - val_loss: 0.5886 - val_accuracy: 0.9359
# Epoch 40/50
# 5/5 [==============================] - 11s 2s/step - loss: 0.6870 - accuracy: 0.8015 - val_loss: 0.6593 - val_accuracy: 0.8846
# Epoch 41/50
# 5/5 [==============================] - 11s 2s/step - loss: 0.6309 - accuracy: 0.7786 - val_loss: 0.5443 - val_accuracy: 0.9103
# Epoch 42/50
# 5/5 [==============================] - 11s 3s/step - loss: 0.7054 - accuracy: 0.7481 - val_loss: 0.5478 - val_accuracy: 0.9103
# Epoch 43/50
# 5/5 [==============================] - 11s 3s/step - loss: 0.6834 - accuracy: 0.7786 - val_loss: 0.5028 - val_accuracy: 0.9231
# Epoch 44/50
# 5/5 [==============================] - 11s 2s/step - loss: 0.6136 - accuracy: 0.7786 - val_loss: 0.4915 - val_accuracy: 0.9487
# Epoch 45/50
# 5/5 [==============================] - 12s 2s/step - loss: 0.5173 - accuracy: 0.8397 - val_loss: 0.4622 - val_accuracy: 0.8974
# Epoch 46/50
# 5/5 [==============================] - 12s 2s/step - loss: 0.4925 - accuracy: 0.8168 - val_loss: 0.3464 - val_accuracy: 0.9615
# Epoch 47/50
# 5/5 [==============================] - 12s 2s/step - loss: 0.3889 - accuracy: 0.8931 - val_loss: 0.3099 - val_accuracy: 0.9615
# Epoch 48/50
# 5/5 [==============================] - 11s 3s/step - loss: 0.4342 - accuracy: 0.8779 - val_loss: 0.2639 - val_accuracy: 0.9615
# Epoch 49/50
# 5/5 [==============================] - 11s 2s/step - loss: 0.3911 - accuracy: 0.8855 - val_loss: 0.3304 - val_accuracy: 0.9103
# Epoch 50/50
# 5/5 [==============================] - 11s 2s/step - loss: 0.4938 - accuracy: 0.8321 - val_loss: 0.3375 - val_accuracy: 0.8974

# %%
model.save('/content/drive/MyDrive/Baitap_AI/tien_VN/money.h5')

# %%
pic = image.load_img('/content/drive/MyDrive/Tiền/train/500k/243408001bbddae383ac311.jpg', target_size=(120,120)) 
plt.imshow(pic)
pic = img_to_array(pic)
pic = pic.reshape(1,120,120,3) 
pic = pic.astype('float32')
pic = pic/255
np.argmax(model.predict(pic), axis=1)
# Out:
# array([8])

# %%
guess=np.argmax(model.predict(pic), axis=1)

# %%
if guess[0]==0:
  print("Loai tien: 1000")
if guess[0]==1:
  print("Loai tien: 10000")
if guess[0]==2:
  print("Loai tien: 100000")
if guess[0]==3:
  print("Loai tien: 200")
if guess[0]==4:
  print("Loai tien: 2000")
if guess[0]==5:
  print("Loai tien: 20000")
if guess[0]==6:
  print("Loai tien: 200000")
if guess[0]==7:
  print("Loai tien: 5000")
if guess[0]==8:
  print("Loai tien: 500000")
if guess[0]==9:
  print("Loai tien: 50000")
if guess[0]==10:
  print("Loai tien: 500")
# Out:
# Loai tien: 500000
